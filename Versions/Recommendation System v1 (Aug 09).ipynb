# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing the data and declaring attributes:

# %%
data = pd.read_csv('productsdataaditi.csv')
cols = ['Id', 'Product_name', 'Category', 'Price', 'Rating', 'Brand']

# %% [markdown]
# app

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def create_sim():
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(data['all'])
    sim = cosine_similarity(count_matrix)
    return data,sim

def rec(product):
    try:
        data.head()
        sim.shape
    except:
        data, sim = create_sim()
    if m not in data['Product_name'].unique():
        return('Not found in our store')
    else:
        i = data.loc[data['Product_name']==product].index[0]
        lst = list(enumerate(sim[i]))
        lst = sorted(lst, key = lambda x:x[1] ,reverse=True)
        lst = lst[1:11]
        l = []
        for i in range(len(lst)):
            a = lst[i][0]
            l.append(data['Product_name'][a])
        return l

# %%
from flask import Flask, render_template, request
app = Flask(__name__)

@app.route("/")
def home():
    return render_template('home.html')

# %%
@app.route("/recommend")
def recommend():
    product = request.args.get('product')
    r = rec(product)
    product = product.upper()
    if type(r)==type('string'):
        return render_template('recommend.html',product=product,r=r,t='s')
    else:
        return render_template('recommend.html',product=product,r=r,t='l')
if __name__ == '__main__':
    app.run()
